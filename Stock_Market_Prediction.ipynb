# %% [markdown]
# <a href="https://colab.research.google.com/github/kriti524/Stock-Market-Prediction/blob/main/Stock_Market_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

# %%
START = "2010-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

# %%
data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  293.813263  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  293.891266  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  287.246124  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  279.252594  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  273.545471  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
# <ipython-input-4-8097d146b7ad>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(['Date', 'Adj Close'], axis = 1)
# Price        Close        High         Low        Open   Volume
# Ticker      TCS.NS      TCS.NS      TCS.NS      TCS.NS   TCS.NS
# 0       375.825012  379.450012  374.524994  377.399994  1963682
# 1       375.924988  379.774994  373.274994  377.500000  2014488
# 2       367.424988  376.100006  366.500000  375.924988  3349176
# 3       357.200012  369.700012  355.500000  367.750000  6474892
# 4       349.899994  359.250000  348.250000  358.000000  6048178

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

# %%
df
# Out:
# Price         Close         High          Low         Open   Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# 0        375.825012   379.450012   374.524994   377.399994  1963682
# 1        375.924988   379.774994   373.274994   377.500000  2014488
# 2        367.424988   376.100006   366.500000   375.924988  3349176
# 3        357.200012   369.700012   355.500000   367.750000  6474892
# 4        349.899994   359.250000   348.250000   358.000000  6048178
# ...             ...          ...          ...          ...      ...
# 3665    4147.000000  4169.750000  4117.649902  4155.000000  1648039
# 3666    4198.700195  4234.299805  4117.649902  4128.200195  1406487
# 3667    4197.399902  4218.000000  4164.350098  4216.000000  1587640
# 3668    4150.350098  4196.750000  4131.049805  4178.100098  1098813
# 3669    4145.899902  4160.000000  4116.450195  4135.000000  1825432
#
# [3670 rows x 5 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3665    4221.610991
# 3666    4225.580994
# 3667    4229.682493
# 3668    4233.078494
# 3669    4236.369492
#
# [3670 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3665    4081.701249
# 3666    4083.271749
# 3667    4084.745748
# 3668    4085.782249
# 3669    4087.220498
#
# [3670 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (2569, 7)
# (1101, 7)

# %%
train.head()
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  293.813263  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  293.891266  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  287.246124  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  279.252594  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  273.545471  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
test.head()
# Out:
# Price                       Date    Adj Close        Close         High  \
# Ticker                                 TCS.NS       TCS.NS       TCS.NS
# 2569   2020-06-10 00:00:00+00:00  1945.980713  2108.750000  2132.000000
# 2570   2020-06-11 00:00:00+00:00  1908.053223  2067.649902  2105.000000
# 2571   2020-06-12 00:00:00+00:00  1882.075928  2039.500000  2049.199951
# 2572   2020-06-15 00:00:00+00:00  1873.217163  2029.900024  2059.000000
# 2573   2020-06-16 00:00:00+00:00  1887.889771  2045.800049  2073.949951
#
# Price           Low         Open   Volume
# Ticker       TCS.NS       TCS.NS   TCS.NS
# 2569    2073.500000  2077.050049  5168397
# 2570    2061.800049  2100.000000  2269513
# 2571    2011.000000  2011.199951  2842642
# 2572    2000.949951  2039.099976  2399022
# 2573    2031.000000  2065.000000  2146528

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.01671754],
#        [0.01606246],
#        [0.01251195],
#        ...,
#        [0.88968517],
#        [0.90110973],
#        [0.90014016]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2469, 100, 1)

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 27s 258ms/step - loss: 0.0873 - mean_absolute_error: 0.2150
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - loss: 0.0080 - mean_absolute_error: 0.0625
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 38s 280ms/step - loss: 0.0076 - mean_absolute_error: 0.0610
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - loss: 0.0072 - mean_absolute_error: 0.0585
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 279ms/step - loss: 0.0063 - mean_absolute_error: 0.0557
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 282ms/step - loss: 0.0058 - mean_absolute_error: 0.0543
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 269ms/step - loss: 0.0054 - mean_absolute_error: 0.0506
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 265ms/step - loss: 0.0063 - mean_absolute_error: 0.0540
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 280ms/step - loss: 0.0049 - mean_absolute_error: 0.0483
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 278ms/step - loss: 0.0048 - mean_absolute_error: 0.0467
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 282ms/step - loss: 0.0063 - mean_absolute_error: 0.0536
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 272ms/step - loss: 0.0051 - mean_absolute_error: 0.0483
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 259ms/step - loss: 0.0041 - mean_absolute_error: 0.0443
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 281ms/step - loss: 0.0046 - mean_absolute_error: 0.0461
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 277ms/step - loss: 0.0040 - mean_absolute_error: 0.0425
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 271ms/step - loss: 0.0040 - mean_absolute_error: 0.0432
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 282ms/step - loss: 0.0038 - mean_absolute_error: 0.0432
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 282ms/step - loss: 0.0041 - mean_absolute_error: 0.0434
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 272ms/step - loss: 0.0035 - mean_absolute_error: 0.0408
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 257ms/step - loss: 0.0037 - mean_absolute_error: 0.0419
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 279ms/step - loss: 0.0038 - mean_absolute_error: 0.0430
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 20s 262ms/step - loss: 0.0031 - mean_absolute_error: 0.0387
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 281ms/step - loss: 0.0035 - mean_absolute_error: 0.0415
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 264ms/step - loss: 0.0033 - mean_absolute_error: 0.0390
# Epoch 25/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 283ms/step - loss: 0.0032 - mean_absolute_error: 0.0394
# Epoch 26/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 282ms/step - loss: 0.0033 - mean_absolute_error: 0.0392
# Epoch 27/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 265ms/step - loss: 0.0027 - mean_absolute_error: 0.0371
# Epoch 28/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 282ms/step - loss: 0.0028 - mean_absolute_error: 0.0374
# Epoch 29/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 282ms/step - loss: 0.0029 - mean_absolute_error: 0.0376
# Epoch 30/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 20s 260ms/step - loss: 0.0028 - mean_absolute_error: 0.0377
# Epoch 31/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 276ms/step - loss: 0.0029 - mean_absolute_error: 0.0379
# Epoch 32/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 259ms/step - loss: 0.0029 - mean_absolute_error: 0.0378
# Epoch 33/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 279ms/step - loss: 0.0029 - mean_absolute_error: 0.0377
# Epoch 34/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - loss: 0.0026 - mean_absolute_error: 0.0356
# Epoch 35/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 262ms/step - loss: 0.0028 - mean_absolute_error: 0.0375
# Epoch 36/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 280ms/step - loss: 0.0025 - mean_absolute_error: 0.0350
# Epoch 37/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - loss: 0.0029 - mean_absolute_error: 0.0375
# Epoch 38/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 282ms/step - loss: 0.0029 - mean_absolute_error: 0.0382
# Epoch 39/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 0.0022 - mean_absolute_error: 0.0338
# Epoch 40/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 258ms/step - loss: 0.0027 - mean_absolute_error: 0.0363
# Epoch 41/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 280ms/step - loss: 0.0027 - mean_absolute_error: 0.0374
# Epoch 42/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 262ms/step - loss: 0.0026 - mean_absolute_error: 0.0364
# Epoch 43/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 263ms/step - loss: 0.0027 - mean_absolute_error: 0.0382
# Epoch 44/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 277ms/step - loss: 0.0023 - mean_absolute_error: 0.0343
# Epoch 45/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 20s 258ms/step - loss: 0.0025 - mean_absolute_error: 0.0368
# Epoch 46/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 280ms/step - loss: 0.0025 - mean_absolute_error: 0.0372
# Epoch 47/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 274ms/step - loss: 0.0023 - mean_absolute_error: 0.0349
# Epoch 48/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 259ms/step - loss: 0.0024 - mean_absolute_error: 0.0343
# Epoch 49/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 282ms/step - loss: 0.0024 - mean_absolute_error: 0.0362
# Epoch 50/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 279ms/step - loss: 0.0023 - mean_absolute_error: 0.0344
# Epoch 51/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 281ms/step - loss: 0.0024 - mean_absolute_error: 0.0349
# Epoch 52/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 260ms/step - loss: 0.0023 - mean_absolute_error: 0.0342
# Epoch 53/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 282ms/step - loss: 0.0022 - mean_absolute_error: 0.0341
# Epoch 54/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 283ms/step - loss: 0.0024 - mean_absolute_error: 0.0361
# Epoch 55/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 20s 261ms/step - loss: 0.0023 - mean_absolute_error: 0.0354
# Epoch 56/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 283ms/step - loss: 0.0025 - mean_absolute_error: 0.0365
# Epoch 57/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 268ms/step - loss: 0.0021 - mean_absolute_error: 0.0335
# Epoch 58/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - loss: 0.0023 - mean_absolute_error: 0.0341
# Epoch 59/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 280ms/step - loss: 0.0021 - mean_absolute_error: 0.0334
# Epoch 60/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 271ms/step - loss: 0.0022 - mean_absolute_error: 0.0339
# Epoch 61/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 281ms/step - loss: 0.0021 - mean_absolute_error: 0.0329
# Epoch 62/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 280ms/step - loss: 0.0022 - mean_absolute_error: 0.0327
# Epoch 63/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 281ms/step - loss: 0.0024 - mean_absolute_error: 0.0351
# Epoch 64/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 272ms/step - loss: 0.0024 - mean_absolute_error: 0.0354
# Epoch 65/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 259ms/step - loss: 0.0024 - mean_absolute_error: 0.0347
# Epoch 66/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 283ms/step - loss: 0.0022 - mean_absolute_error: 0.0345
# Epoch 67/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 276ms/step - loss: 0.0021 - mean_absolute_error: 0.0334
# Epoch 68/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 259ms/step - loss: 0.0022 - mean_absolute_error: 0.0343
# Epoch 69/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 282ms/step - loss: 0.0023 - mean_absolute_error: 0.0338
# Epoch 70/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 281ms/step - loss: 0.0022 - mean_absolute_error: 0.0335
# Epoch 71/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 267ms/step - loss: 0.0023 - mean_absolute_error: 0.0348
# Epoch 72/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 259ms/step - loss: 0.0020 - mean_absolute_error: 0.0318
# Epoch 73/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 283ms/step - loss: 0.0020 - mean_absolute_error: 0.0324
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 275ms/step - loss: 0.0024 - mean_absolute_error: 0.0356
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 259ms/step - loss: 0.0021 - mean_absolute_error: 0.0333
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 281ms/step - loss: 0.0021 - mean_absolute_error: 0.0335
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 276ms/step - loss: 0.0023 - mean_absolute_error: 0.0350
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 39s 256ms/step - loss: 0.0021 - mean_absolute_error: 0.0328
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 281ms/step - loss: 0.0021 - mean_absolute_error: 0.0329
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 281ms/step - loss: 0.0022 - mean_absolute_error: 0.0340
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - loss: 0.0023 - mean_absolute_error: 0.0350
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 283ms/step - loss: 0.0022 - mean_absolute_error: 0.0337
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 283ms/step - loss: 0.0020 - mean_absolute_error: 0.0312
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 264ms/step - loss: 0.0021 - mean_absolute_error: 0.0327
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 278ms/step - loss: 0.0020 - mean_absolute_error: 0.0327
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 278ms/step - loss: 0.0020 - mean_absolute_error: 0.0319
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 260ms/step - loss: 0.0019 - mean_absolute_error: 0.0312
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 280ms/step - loss: 0.0022 - mean_absolute_error: 0.0335
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 276ms/step - loss: 0.0021 - mean_absolute_error: 0.0331
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 267ms/step - loss: 0.0019 - mean_absolute_error: 0.0309
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 271ms/step - loss: 0.0020 - mean_absolute_error: 0.0319
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 47s 350ms/step - loss: 0.0021 - mean_absolute_error: 0.0326
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 36s 283ms/step - loss: 0.0021 - mean_absolute_error: 0.0329
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 43s 311ms/step - loss: 0.0019 - mean_absolute_error: 0.0314
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 276ms/step - loss: 0.0022 - mean_absolute_error: 0.0334
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 43s 301ms/step - loss: 0.0024 - mean_absolute_error: 0.0357
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 290ms/step - loss: 0.0020 - mean_absolute_error: 0.0323
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 265ms/step - loss: 0.0023 - mean_absolute_error: 0.0334
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 43s 290ms/step - loss: 0.0020 - mean_absolute_error: 0.0315
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - loss: 0.0019 - mean_absolute_error: 0.0311

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_close.shape
# Out:
# (1101, 1)

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %%
import pandas as pd # Make sure pandas is imported.

final_df = pd.concat([past_100_days, test_df], ignore_index=True)
# Use pd.concat to combine the DataFrames.
# Pass the DataFrames as a list to pd.concat.

# %%
final_df.head()
# Out:
#              0
# 0  2208.000000
# 1  2184.699951
# 2  2195.000000
# 3  2194.199951
# 4  2215.000000

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.23352017],
#        [0.22576886],
#        [0.22919542],
#        ...,
#        [0.88434608],
#        [0.87326795],
#        [0.86841105]])

# %%
input_data.shape
# Out:
# (1201, 1)

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1101, 100, 1)
# (1101,)

# %%
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step

# %%
y_pred.shape
# Out:
# (1101, 1)

# %%
y_test
# Out:
# array([0.18877558, 0.18488332, 0.16798349, ..., 0.88434608, 0.87326795,
#        0.86841105])

# %%
y_pred
# Out:
# array([[0.22467561],
#        [0.22857954],
#        [0.2324273 ],
#        ...,
#        [0.79429626],
#        [0.8109113 ],
#        [0.8248893 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00033267])

# %%
scale_factor = 1/0.00041967
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 6.49%

# %%
from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.9242053933531864

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
